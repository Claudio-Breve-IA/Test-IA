# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

def cargar_y_predecir(ruta_imagen, modelo):
    # Cargar y preprocesar la imagen
    img = image.load_img(ruta_imagen, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    
    # Hacer predicción
    prediccion = modelo.predict(img_array)
    if prediccion > 0.5:
        print("La manzana es de buena calidad")
    else:
        print("La manzana es de mala calidad")
a=r'C:\Users\claud\OneDrive\Escritorio\Python\Temp\train\buena\FreshApple (1)'
# Ruta a la imagen de prueba
ruta_imagen_prueba =r'C:\Users\claud\OneDrive\Escritorio\Python\Apple__Healthy\FreshApple (8).jpg'# r'C:\Users\claud\OneDrive\Escritorio\Python\Apple__Rotten\rotated_by_15_Screen Shot 2018-06-07 at 2.15.20 PM.png'
cargar_y_predecir(ruta_imagen_prueba, modelo_cargado)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# La manzana es de mala calidad

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo guardado
model = tf.keras.models.load_model('modelo_manzanas_100.h5')

# Función para preprocesar la imagen
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalizar la imagen
    return img_array

# Función para hacer la predicción
def predict_image(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)
    return prediction[0][0]

# Función para mostrar la imagen y la predicción
def show_prediction(img_path):
    img = image.load_img(img_path, target_size=(150, 150))
    prediction = predict_image(img_path)
    label = 'Buena' if prediction < 0.5 else 'Mala'
    
    plt.imshow(img)
    plt.title(f'Predicción: {label}')
    plt.axis('off')
    plt.show()
a=r'C:\Users\claud\OneDrive\Escritorio\Python\Temp\train\buena\FreshApple (1).jpg'
b=r'C:\Users\claud\OneDrive\Escritorio\Python\Apple__Healthy\FreshApple (8).jpg'
c=r'C:\Users\claud\OneDrive\Escritorio\Python\Apple__Rotten\rotated_by_15_Screen Shot 2018-06-07 at 2.15.20 PM.png'
# Ruta a la imagen de prueba
# Probar el modelo con nuevas imágenes
# Reemplaza 'path_to_new_image.jpg' con la ruta a tu imagen
new_images = [a, b, c]
for img_path in new_images:
    show_prediction(img_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Cargar el modelo entrenado
model = tf.keras.models.load_model('modelo_manzanas_100.h5')

# Función para cargar y preprocesar una imagen
def load_and_preprocess_image(img_path, target_size=(150, 150)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalización
    return img_array

# Función para predecir la calidad de la manzana con detalles
def predict_image_quality(img_path):
    img_array = load_and_preprocess_image(img_path)
    prediction = model.predict(img_array)
    confidence = prediction[0][0]
    if confidence > 0.5:
        result = "Mala"
    else:
        result = "Buena"
    return result, confidence
a=r'C:\Users\claud\OneDrive\Escritorio\Python\Temp\train\buena\FreshApple (1).jpg'
b=r'C:\Users\claud\OneDrive\Escritorio\Python\Apple__Healthy\FreshApple (8).jpg'
c=r'C:\Users\claud\OneDrive\Escritorio\Python\Apple__Rotten\rotated_by_15_Screen Shot 2018-06-07 at 2.15.20 PM.png'
# Ruta a la imagen de prueba
# Probar el modelo con nuevas imágenes
# Reemplaza 'path_to_new_image.jpg' con la ruta a tu imagen
test_images = [a, b, c]

# Realizar predicciones y mostrar resultados con detalles
for img_path in test_images:
    result, confidence = predict_image_quality(img_path)
    img = image.load_img(img_path)
    
    # Mostrar la imagen con detalles de predicción
    plt.imshow(img)
    plt.title(f'Predicción: {result}\nConfianza: {confidence:.2f}')
    plt.axis('off')
    plt.show()

    # Información detallada de la predicción
    print(f"Imagen: {img_path}")
    print(f"Predicción: {result}")
    print(f"Confianza: {confidence:.2f}")
    print("-" * 50)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Imagen: C:\Users\claud\OneDrive\Escritorio\Python\Temp\train\buena\FreshApple (1).jpg
# Predicción: Buena
# Confianza: 0.05
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagen: C:\Users\claud\OneDrive\Escritorio\Python\Apple__Healthy\FreshApple (8).jpg
# Predicción: Buena
# Confianza: 0.00
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagen: C:\Users\claud\OneDrive\Escritorio\Python\Apple__Rotten\rotated_by_15_Screen Shot 2018-06-07 at 2.15.20 PM.png
# Predicción: Mala
# Confianza: 0.97
# --------------------------------------------------

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Generar predicciones en el conjunto de prueba
test_generator.reset()
predicciones = modelo_cargado.predict(test_generator)
predicciones_binarias = np.where(predicciones > 0.5, 1, 0).flatten()

# Obtener las etiquetas reales
etiquetas_reales = test_generator.classes

# Crear la matriz de confusión
cm = confusion_matrix(etiquetas_reales, predicciones_binarias)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicción')
plt.ylabel('Realidad')
plt.title('Matriz de Confusión')
plt.show()

# Informe de clasificación
print(classification_report(etiquetas_reales, predicciones_binarias, target_names=list(test_generator.class_indices.keys())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 import numpy as np
#       7 # Generar predicciones en el conjunto de prueba
# ----> 8 test_generator.reset()
#       9 predicciones = modelo_cargado.predict(test_generator)
#      10 predicciones_binarias = np.where(predicciones > 0.5, 1, 0).flatten()
#
# NameError: name 'test_generator' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Crear un generador de datos de prueba
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    r'C:\Users\claud\OneDrive\Escritorio\Python\Temp\validation',  # Cambia esto a la ruta de tu carpeta de prueba
    target_size=(150, 150),  # Mismo tamaño que en el entrenamiento
    batch_size=32,
    class_mode='binary'
)
# Evaluar el modelo en el conjunto de prueba
resultado = modelo_cargado.evaluate(test_generator)
print(f"Pérdida en el conjunto de prueba: {resultado[0]}")
print(f"Precisión en el conjunto de prueba: {resultado[1]}")
# Out:
# Found 2683 images belonging to 2 classes.
# C:\Users\claud\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9901 - loss: 0.0803
# Pérdida en el conjunto de prueba: 0.06460362672805786
# Precisión en el conjunto de prueba: 0.9910547733306885

# %%
import pickle

# Ruta al archivo .pkl
ruta_archivo = r'C:\Users\claud\OneDrive\Escritorio\Python\historial_entrenamiento.pkl'

# Cargar el archivo .pkl
with open(ruta_archivo, 'rb') as archivo:
    historial = pickle.load(archivo)

print(historial.keys())

# Imprimir algunas de las métricas
for clave, valor in historial.items():
    print(f"{clave}: {valor[:5]}")  # Imprime las primeras 5 entradas de cada métrica
import matplotlib.pyplot as plt

# Supongamos que el historial tiene claves como 'accuracy', 'val_accuracy', 'loss', 'val_loss'
plt.figure(figsize=(12, 6))

# Gráfico de precisión
plt.subplot(1, 2, 1)
plt.plot(historial['accuracy'], label='Precisión de entrenamiento')
plt.plot(historial['val_accuracy'], label='Precisión de validación')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend(loc='lower right')
plt.title('Precisión de Entrenamiento y Validación')

# Gráfico de pérdida
plt.subplot(1, 2, 2)
plt.plot(historial['loss'], label='Pérdida de entrenamiento')
plt.plot(historial['val_loss'], label='Pérdida de validación')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend(loc='upper right')
plt.title('Pérdida de Entrenamiento y Validación')

plt.tight_layout()
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# accuracy: [0.628731369972229, 0.7432835698127747, 0.825373113155365, 0.8567163944244385, 0.8675373196601868]
# loss: [11.837384223937988, 0.5121983885765076, 0.4018881618976593, 0.3413398265838623, 0.3070189654827118]
# val_accuracy: [0.708907961845398, 0.8169959187507629, 0.8542675971984863, 0.827059268951416, 0.8497949838638306]
# val_loss: [0.5857287645339966, 0.40402722358703613, 0.33191683888435364, 0.38904058933258057, 0.3744111657142639]
