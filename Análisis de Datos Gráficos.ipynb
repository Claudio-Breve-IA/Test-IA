# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from pylab import *      # importar todas las funciones de pylab

# %%
plot([1,-1,0,3,-1])                  # generar el gráfico del arrego con coordenadas Y
show()                   # mostrar el gráfico en pantalla

# %%
#from pylab import *      # importar todas las funciones de pylab


plot([1,-1,0,3,-1],[1,-1,0,3,-1])                  # generar el gráfico coordenadas x , y de dos array


show()                   # mostrar el gráfico en pantalla

# %%
#cargamos los datos de entrada
data = pd.read_excel(r"C:\Users\claud\OneDrive\Escritorio\Python\ordenar csv\archivo_ordenado_Agua_Pota.xlsx")
#veamos cuantas dimensiones y registros contiene
data.shape
# Out:
# (3276, 10)

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  0.000000  214.846144  49456.587108     7.897539         NaN    583.448849
# 1  0.227499  152.530111  39028.599340     3.462492  283.693782    443.029232
# 2  0.975578  221.204114  31145.110739     7.615583  333.677843    439.112765
# 3  0.989912  133.216942  16922.853899     9.293289  444.375731    322.291191
# 4  1.431782  228.130383  12937.246891     6.214773  319.734136    495.379883
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0        7.702328        77.712891   4.928840           0
# 1       13.201943        62.322711   3.545741           1
# 2       21.145954              NaN   2.533996           0
# 3       10.430076        43.578466   5.160604           1
# 4       12.033344        61.141119   4.948443           0

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
data.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# ...

# %%
plt.figure(figsize=(10,8))

sns.heatmap(data.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 plt.figure(figsize=(10,8))
# ----> 3 sns.heatmap(data.corr(),annot=True)
#
# NameError: name 'sns' is not defined

# %%
data.hist()
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

plt.show()

# %%
# Vamos a RECORTAR los datos en la zona donde se concentran más los puntos
# esto es en el eje X: entre 0 y 3.500
# y en el eje Y: entre 0 y 80.000
filtered_data = data[(data['Word count'] <= 3500) & (data['# Shares'] <= 80000)]
 
colores=['orange','blue']
tamanios=[30,60]
 
f1 = filtered_data['Word count'].values
f2 = filtered_data['# Shares'].values
 
# Vamos a pintar en colores los puntos por debajo y por encima de la media de Cantidad de Palabras
asignar=[]
for index, row in filtered_data.iterrows():
    if(row['Word count']>1808):
        asignar.append(colores[0])
    else:
        asignar.append(colores[1])
    
plt.scatter(f1, f2, c=asignar, s=tamanios[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Word count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 4
# ...

# %%
plt.figure(figsize=(20,8))

sb.countplot(data['# of Links'])

plt.savefig('diagrama_tipo.png')
plt.show()

# %%
dataframe = pd.read_csv(r"D:\Datos\DATOS\AMT\PEN1\KINGSTONAMT (J)\duoc2007\2022-1\MDY7101 Mineria de Datos\Mineria de Datos 2020-1\Anaconda\ClusteringKmeans\analisis.csv")
dataframe.head()


# En este caso seleccionamos 3 dimensiones: op, ex y ag 
# y las cruzamos para ver si nos dan alguna pista de su agrupación y la relación con sus categorías.
sb.pairplot(dataframe.dropna(), hue='categoria',size=4,vars=["op","ex","ag"],kind='scatter')
# Out:
# C:\Users\arman\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
